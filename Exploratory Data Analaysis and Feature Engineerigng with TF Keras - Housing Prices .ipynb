# %%
#Exploratory data Analysis and Feature Engineering

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np

# %%
# loading kaggle dataset - historical picing data for house sales
df = pd.read_csv('../DATA/kc_house_data.csv')

# %%
# finding any null values or data - returns true , we have no missing data 
# this returns the sum or amount of missing data for each column 
df.isnull( ).sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
#
df.describe()#.transpose()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007547      0.234292      3.409825
# ...

# %%
# since we have continuous values - a dsitrbution plot is good to observe the dsitrbution of the data 
plt.figure(figsize =(10,6))
sns.displot(df['price'])
# this shows that most ofthe houses have the price 0 and 2 mill dollars the rest seem to be outliers

# %%
# to analyse different features, some categorical features 
sns.countplot(df['bedrooms'])
# Out:
# <Axes: ylabel='count'>

# %%
# to observe what correlates with the label 
df.corr()
# Out:
# /var/folders/zw/3n2l0psn3hg_j1cpyxxfkgfr0000gn/T/ipykernel_40658/1657714133.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# ...

# %%
##to observe what correlates with the price , but also to sort the values 
df.corr()['price'].sort_values()
# rthis shows that the sqft_lviing, gradem sqft above have a high correlation with price
# Out:
# /var/folders/zw/3n2l0psn3hg_j1cpyxxfkgfr0000gn/T/ipykernel_40658/332038565.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['price'].sort_values()
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
# knowing the features that have a high correlation with the label we can then use this to plot 
# generating scatterpltos wiht features highly correlated to the labels
plt.figure(figsize=(10,5))
sns.scatterplot(x='price', y='sqft_living', data=df)
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
#
plt.figure(figsize=(10,5))
sns.boxplot(x='bedrooms', y='price', data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
#in datset there aer lat and long data - latiutude and longitude cn use matplotlib to plot these points

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# this showsthat there is some sort of price distribution with the longitude of a house
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='long', data= df)
# Out:
# <Axes: xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='lat', data= df)
# at particular latitude there is an expensive area
# we can look at the map to compare this
# Out:
# <Axes: xlabel='price', ylabel='lat'>

# %%
# to find hotspots ont he map - make sure to plot long- x and y as lat to avoid flipping the coordinates 
plt.figure(figsize=(12,8))
sns.scatterplot(x='long', y='lat',data=df, hue = 'price')
# by plotting the latitude and longitude of houses we build a map of the aera s
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
df.sort_values('price',ascending=False).head(20)
# based on this tabel and the first dist plot there are only a few houses above the price of 3 mill  so we can classify these as outliers
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)*0.01
# Out:
# 215.97

# %%
# to sample the data to use without the outliers, to grab 99% of the houses 
# this was done so that the hue difference is more clear in the long vs lat scatter plot
non_top_1perc = df.sort_values('price',ascending=False).iloc[216:]

# %%
# now we get a colour distribution that is alot clearer
# now we cna see where the more expensive areas are 
plt.figure(figsize=(12,8))
sns.scatterplot(x='long', y='lat',data=non_top_1perc, hue = 'price', palette = 'RdYlGn')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
# boxplot to see prices of households ont he waterfront 
# this shows that if on waterfront - 1 - more likelt to be more expensive 
sns.boxplot(x='waterfront', y='price', data = df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
# now to review the data - FEATURE Engineering

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
# remove the iid column
df= df.drop('id', axis = 1)

# %%
# examint he datcolumn  and convert to a date time object - this is essnrtial for feature engineering 

df['date'] = pd.to_datetime(df['date'])

# %%
# creating new columns to extract data in the strings using the datetime method
df['year'] = df['date'].apply(lambda date: date.year)
df['month'] = df['date'].apply(lambda date: date.month)

# %%
# now we can do some exploratory data analysis to see if these are some useful features in general 
    
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
# to see trends with year or month , grouping by month and seeing the impact on the label - price 
# from this it is not easy to see the variaiton or trend with the month 
plt.figure(figsize=(10,6))
sns.boxplot(x='month', y='price', data = df)
# Out:
# <Axes: xlabel='month', ylabel='price'>

# %%
# since the boxplot was not a clear indication we could plot the 
df.groupby('month').mean()['price'].plot()
# Out:
# /var/folders/zw/3n2l0psn3hg_j1cpyxxfkgfr0000gn/T/ipykernel_40658/3759475649.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('month').mean()['price'].plot()
# <Axes: xlabel='month'>

# %%
df.groupby('year').mean()['price'].plot()
# Out:
# /var/folders/zw/3n2l0psn3hg_j1cpyxxfkgfr0000gn/T/ipykernel_40658/3176732454.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('year').mean()['price'].plot()
# <Axes: xlabel='year'>

# %%
# now we can remove the original date column
df = df.drop('date', axis = 1)

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month
# ...

# %%
# take note of the zipcode clumnn -numerical , the mode will assume its a continuours feature
# this is where domain experience is needed and so where understanding if value  increases in orderely way
# upon observation it is clear that the distrubtion of zip code is not in an order so this feature needs to be treated as a categry

# %%
# there are 70 unique zip codes which is not feasible for creating dummy varibaes 
# therefore the best thing to do is either drop this or section this into cheaper or more expensive zip codes or zip codes int he north east , west south etc. 

#df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
# to drop the zip code coumns 
df = df.drop('zipcode', axis = 1)

# %%
# more recent year , more recent renovation higher price -more value 
# possible feature engineering categorising it into renovated and not renovated 1 or 0


df['yr_renovated'].value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
# coninuing process of deciding whether to make continuous feature cateogrical or keeping it as it is 
df['sqft_basement'].value_counts()
# these also show that forhouses that have basements thaey are morelikely to have more value.
# Out:
# 0      13110
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
# separating FEATURES FROM Label

# %%
# when passing X and y it is .values is important as tensorflow cannot compute a df or series that well so this puts it back into arraty form
X = df.drop('price',axis=1).values
y = df['price'].values

# %%
# now testtrainsplit 
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
# scaling and transforming the train set 
X_train = scaler.fit_transform(X_train)

# %%
# Now doing the same for the test set but instead only trasnform dont fit 
X_test = scaler.fit_transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# OBSERVING THE SHAPE OF TRAIN DATA 
X_train.shape
# since 19 features - good start for 19 neurons in layers
# Out:
# (15117, 19)

# %%
model = Sequential()

model.add(Dense(19,activation ='relu'))
model.add(Dense(19,activation ='relu'))
model.add(Dense(19,activation ='relu'))
model.add(Dense(19,activation ='relu'))

model.add(Dense(1))
# compiling model with an adam optmiser and mean squared error loss 
model.compile(optimizer='adam', loss= 'mse')

# %%
model.fit(x=X_train, y=y_train,
          validation_data =(X_test,y_test),
         batch_size = 128, epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 1s 2ms/step - loss: 430247608320.0000 - val_loss: 418958770176.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 925us/step - loss: 429543915520.0000 - val_loss: 416434356224.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 899us/step - loss: 417349795840.0000 - val_loss: 388866834432.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 867us/step - loss: 352097468416.0000 - val_loss: 285255860224.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 887us/step - loss: 207991357440.0000 - val_loss: 138601824256.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 2ms/step - loss: 109111304192.0000 - val_loss: 97122951168.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 1ms/step - loss: 97840529408.0000 - val_loss: 94435819520.0000
# Epoch 8/400
# ...

# %%
# explore the model history - now we can convert this to a df 
#cna compre oss on training and loss on valiadtion 
pd.DataFrame(model.history.history)
# Out:
#              loss      val_loss
# 0    4.302476e+11  4.189588e+11
# 1    4.295439e+11  4.164344e+11
# 2    4.173498e+11  3.888668e+11
# 3    3.520975e+11  2.852559e+11
# 4    2.079914e+11  1.386018e+11
# ..            ...           ...
# 395  2.984333e+10  3.286715e+10
# 396  2.980803e+10  3.376510e+10
# 397  2.982587e+10  3.368857e+10
# 398  2.982123e+10  3.419561e+10
# 399  2.979633e+10  3.406370e+10
#
# [400 rows x 2 columns]

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# here trian loss and val loss both decrease - does not show signs of overfitting 
# CAN COMPARE behaviour or loss and val loss, both lines are the same v close showing it could continue
# Out:
# <Axes: >

# %%
# now for evaluation on test data 
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
predictions = model.predict(X_test)
# Out:
# 203/203 [==============================] - 0s 353us/step

# %%
# if values are too large and hard to interprete
np.sqrt(mean_squared_error(y_test, predictions))
# Out:
# 184563.53059967837

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 112820.13968720613

# %%
# to evaluate the MAE AND MSE we need to look at the dataframe as a whole 
df['price'].describe()
# if we compare the mean value for the price is 540296.6 the MAE is about a 5th of that which is not a good indicatpr
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
# we can also use this metric - Best possible score is 1.0, lower values are worse.
explained_variance_score(y_test, predictions )
# Out:
# 0.7806848940900403

# %%
# we can see that for the really expensive hosues the prediction is bad , so might be worht rertrianig model based on lower priced houses 
plt.figure(figsize=(12,6))
plt.scatter(y_test, predictions)
plt.plot(y_test,y_test, 'r')

# %%
single_house = df.drop('price', axis=1).iloc[0]

# %%
single_house = scaler.transform(single_house.values.reshape(-1,19))

# %%
model.predict(single_house)
# Out:
# 1/1 [==============================] - 0s 95ms/step
# array([[3.83184e+09]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10

# %%
# prediction shows that the predicted values are overshooting for furthee improvemnet 
# it is more ideal to
